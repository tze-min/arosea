# %% [markdown]
# # running mordecai via elasticsearch
#
# set up mordecai via https://github.com/ryerson-ggl/mordecai-geoparser-on-windows
#
# within mordecai-geoparser-on-windows:
# 1. activate mordecai-2.0.1.post1
# 2. run docker container (open Docker Desktop and run geonames_index under Containers/Apps)
# 3. docker ps -f name=geonames_index
# 4. http://localhost:9200/_cat/indices?v
# 5. health status should be yellow; if nothing's shown, consider changing internet service
# 6. run jupyter notebook from within mordecai-2.0.1.post1 environment

# %% [markdown]
# # import data

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', 1000)  # or 1000

d = pd.read_csv("raw/emdat_public_2021_08_08_query_uid-lkltYs.csv")[5:].reset_index(drop=True)
d.columns = d.iloc[0]
d = d[1:].reset_index(drop=True)

d2 = d[d["Location"].notnull()].reset_index(drop=True) # removed 69 rows without Location value
loca = d2[["Dis No", "Location"]]

# %%
loca
# Out:
# 0            Dis No                                           Location
# 0     2000-0372-CHN  Quanzhou, Zhangzhou, Xiamen districts (Fujian ...
# 1     2000-9186-AFG  Kandahar, Hilmand, Nimroz, Zabul, Uruzgan prov...
# 2     2000-0373-BGD  Bakalia, Kotwali, Chandgaon, Pahartali, Hathaz...
# 3     2000-0484-BTN  Pasakha area (Sampheling district, Chhukha pro...
# 4     2000-0677-CHN  Xuwen area (Zhanjiang district, Guandong provi...
# ...             ...                                                ...
# 3420  2020-0216-YEM                      Hadhramaut, Shabwa, Al Mahrah
# 3421  2020-0314-YEM  Marib, Dhale, Abyan, Hadhramaut, Ibb, Hodeidah...
# 3422  2020-0319-YEM  Lahij, Ibb, Shabwah, Abyan and Sana'a governor...
# 3423  2021-0449-YEM  Marib,Taizz, al-Mahrah, Hadramawt, Shabwa, Aby...
# 3424  2020-0131-TLS  Cristo Rei, Nain Feto, Dom Aleixo, and Vera Cr...
#
# [3425 rows x 2 columns]

# %% [markdown]
# # geoparse

# %%
from mordecai import Geoparser
geo = Geoparser()
# Out:
# Models path: C:\Users\TzeMin\miniconda3\envs\mordecai-2.0.1.post1\lib\site-packages\mordecai\models\

# %%
dataf = []
for row in loca.values:
    disno = row[0]
    res = geo.geoparse(row[1])
    
    for d in res:
        if d.get("geo"):
            location = d["word"]
            country = d["geo"]["country_code3"]
            lon, lat = d["geo"]["lon"], d["geo"]["lat"]
            dataf.append([disno, location, country, lon, lat])
        else:
            continue

# %%
df = pd.DataFrame(dataf, columns=["Dis No", "Locat", "CountryCode", "Lon", "Lat"])
df
# Out:
#               Dis No          Locat CountryCode        Lon       Lat
# 0      2000-0372-CHN       Quanzhou         CHN  118.58583  24.91389
# 1      2000-0372-CHN      Zhangzhou         CHN  117.65556  24.51333
# 2      2000-0372-CHN         Xiamen         CHN  118.08187  24.47979
# 3      2000-0372-CHN   Fujian Sheng         CHN        118     26.25
# 4      2000-0372-CHN  Jiangxi Sheng         CHN  115.66667  27.66667
# ...              ...            ...         ...        ...       ...
# 11330  2020-0314-YEM            Ibb         YEM   44.16667        14
# 11331  2021-0449-YEM          Marib         YEM   45.32581  15.46253
# 11332  2021-0449-YEM      Hadramawt         YEM         49        16
# 11333  2021-0449-YEM         Shabwa         YEM         47        15
# 11334  2020-0131-TLS           Dili         TLS  125.66667     -8.55
#
# [11335 rows x 5 columns]

# %%
df.to_csv("processed/results.csv", index=False)

# %% [markdown]
# # finalise data

# %%
df = pd.read_csv("processed/results.csv")
d3 = df.merge(d2, on="Dis No", how="left").reset_index(drop=True)
d3
# Out:
#               Dis No          Locat CountryCode        Lon       Lat  Year  \
# 0      2000-0372-CHN       Quanzhou         CHN  118.58583  24.91389  2000
# 1      2000-0372-CHN      Zhangzhou         CHN  117.65556  24.51333  2000
# 2      2000-0372-CHN         Xiamen         CHN  118.08187  24.47979  2000
# 3      2000-0372-CHN   Fujian Sheng         CHN  118.00000  26.25000  2000
# 4      2000-0372-CHN  Jiangxi Sheng         CHN  115.66667  27.66667  2000
# ...              ...            ...         ...        ...       ...   ...
# 11330  2020-0314-YEM            Ibb         YEM   44.16667  14.00000  2020
# 11331  2021-0449-YEM          Marib         YEM   45.32581  15.46253  2021
# 11332  2021-0449-YEM      Hadramawt         YEM   49.00000  16.00000  2021
# 11333  2021-0449-YEM         Shabwa         YEM   47.00000  15.00000  2021
# 11334  2020-0131-TLS           Dili         TLS  125.66667  -8.55000  2020
#
#         Seq Glide Disaster Group Disaster Subgroup Disaster Type  \
# 0      0372   NaN        Natural      Hydrological         Flood
# 1      0372   NaN        Natural      Hydrological         Flood
# 2      0372   NaN        Natural      Hydrological         Flood
# 3      0372   NaN        Natural      Hydrological         Flood
# 4      0372   NaN        Natural      Hydrological         Flood
# ...     ...   ...            ...               ...           ...
# 11330  0314   NaN        Natural      Hydrological         Flood
# 11331  0449   NaN        Natural      Hydrological         Flood
# 11332  0449   NaN        Natural      Hydrological         Flood
# 11333  0449   NaN        Natural      Hydrological         Flood
# 11334  0131   NaN        Natural      Hydrological         Flood
#
#       Disaster Subtype Disaster Subsubtype Event Name      Country  ISO  \
# 0       Riverine flood                 NaN        NaN        China  CHN
# 1       Riverine flood                 NaN        NaN        China  CHN
# 2       Riverine flood                 NaN        NaN        China  CHN
# 3       Riverine flood                 NaN        NaN        China  CHN
# 4       Riverine flood                 NaN        NaN        China  CHN
# ...                ...                 ...        ...          ...  ...
# 11330              NaN                 NaN        NaN        Yemen  YEM
# 11331              NaN                 NaN        NaN        Yemen  YEM
# 11332              NaN                 NaN        NaN        Yemen  YEM
# 11333              NaN                 NaN        NaN        Yemen  YEM
# 11334   Riverine flood                 NaN        NaN  Timor-Leste  TLS
#
#                    Region Continent  \
# 0            Eastern Asia      Asia
# 1            Eastern Asia      Asia
# 2            Eastern Asia      Asia
# 3            Eastern Asia      Asia
# 4            Eastern Asia      Asia
# ...                   ...       ...
# 11330        Western Asia      Asia
# 11331        Western Asia      Asia
# 11332        Western Asia      Asia
# 11333        Western Asia      Asia
# 11334  South-Eastern Asia      Asia
#
#                                                 Location          Origin  \
# 0      Quanzhou, Zhangzhou, Xiamen districts (Fujian ...  Monsoonal rain
# 1      Quanzhou, Zhangzhou, Xiamen districts (Fujian ...  Monsoonal rain
# 2      Quanzhou, Zhangzhou, Xiamen districts (Fujian ...  Monsoonal rain
# 3      Quanzhou, Zhangzhou, Xiamen districts (Fujian ...  Monsoonal rain
# 4      Quanzhou, Zhangzhou, Xiamen districts (Fujian ...  Monsoonal rain
# ...                                                  ...             ...
# 11330  Marib, Dhale, Abyan, Hadhramaut, Ibb, Hodeidah...     Heavy rains
# 11331  Marib,Taizz, al-Mahrah, Hadramawt, Shabwa, Aby...     Heavy rains
# 11332  Marib,Taizz, al-Mahrah, Hadramawt, Shabwa, Aby...     Heavy rains
# 11333  Marib,Taizz, al-Mahrah, Hadramawt, Shabwa, Aby...     Heavy rains
# 11334  Cristo Rei, Nain Feto, Dom Aleixo, and Vera Cr...     Heavy rains
#
#       Associated Dis                Associated Dis2 OFDA Response Appeal  \
# 0               Rain  Slide (land, mud, snow, rock)           NaN    NaN
# 1               Rain  Slide (land, mud, snow, rock)           NaN    NaN
# 2               Rain  Slide (land, mud, snow, rock)           NaN    NaN
# 3               Rain  Slide (land, mud, snow, rock)           NaN    NaN
# 4               Rain  Slide (land, mud, snow, rock)           NaN    NaN
# ...              ...                            ...           ...    ...
# 11330            NaN                            NaN           NaN    NaN
# 11331            NaN                            NaN           NaN    NaN
# 11332            NaN                            NaN           NaN    NaN
# 11333            NaN                            NaN           NaN    NaN
# 11334            NaN                            NaN           NaN    NaN
#
#       Declaration Aid Contribution Dis Mag Value Dis Mag Scale Latitude  \
# 0             NaN              NaN         76000           Km2      NaN
# 1             NaN              NaN         76000           Km2      NaN
# 2             NaN              NaN         76000           Km2      NaN
# 3             NaN              NaN         76000           Km2      NaN
# 4             NaN              NaN         76000           Km2      NaN
# ...           ...              ...           ...           ...      ...
# 11330         NaN              NaN           NaN           Km2      NaN
# 11331         NaN              NaN           NaN           Km2      NaN
# 11332         NaN              NaN           NaN           Km2      NaN
# 11333         NaN              NaN           NaN           Km2      NaN
# 11334         NaN              NaN           NaN           Km2      NaN
#
#       Longitude Local Time River Basin Start Year Start Month Start Day  \
# 0           NaN        NaN         NaN       2000           6        17
# 1           NaN        NaN         NaN       2000           6        17
# 2           NaN        NaN         NaN       2000           6        17
# 3           NaN        NaN         NaN       2000           6        17
# 4           NaN        NaN         NaN       2000           6        17
# ...         ...        ...         ...        ...         ...       ...
# 11330       NaN        NaN         NaN       2020           8         1
# 11331       NaN        NaN         NaN       2021           7        16
# 11332       NaN        NaN         NaN       2021           7        16
# 11333       NaN        NaN         NaN       2021           7        16
# 11334       NaN        NaN         NaN       2020           3        13
#
#       End Year End Month End Day Total Deaths No Injured No Affected  \
# 0         2000         6      30           43         10         NaN
# 1         2000         6      30           43         10         NaN
# 2         2000         6      30           43         10         NaN
# 3         2000         6      30           43         10         NaN
# 4         2000         6      30           43         10         NaN
# ...        ...       ...     ...          ...        ...         ...
# 11330     2020         8       5           20          6        9000
# 11331     2021         7      28           14        NaN        1000
# 11332     2021         7      28           14        NaN        1000
# 11333     2021         7      28           14        NaN        1000
# 11334     2020         3      13            3          7        9124
#
#       No Homeless Total Affected Reconstruction Costs ('000 US$)  \
# 0           31000          31010                             NaN
# 1           31000          31010                             NaN
# 2           31000          31010                             NaN
# 3           31000          31010                             NaN
# 4           31000          31010                             NaN
# ...           ...            ...                             ...
# 11330         NaN           9006                             NaN
# 11331         NaN           1000                             NaN
# 11332         NaN           1000                             NaN
# 11333         NaN           1000                             NaN
# 11334         NaN           9131                             NaN
#
#       Insured Damages ('000 US$) Total Damages ('000 US$)          CPI  \
# 0                            NaN                    19000  67.35575898
# 1                            NaN                    19000  67.35575898
# 2                            NaN                    19000  67.35575898
# 3                            NaN                    19000  67.35575898
# 4                            NaN                    19000  67.35575898
# ...                          ...                      ...          ...
# 11330                        NaN                      NaN          NaN
# 11331                        NaN                      NaN          NaN
# 11332                        NaN                      NaN          NaN
# 11333                        NaN                      NaN          NaN
# 11334                        NaN                    20000          NaN
#
#       Adm Level                           Admin1 Code  \
# 0           1;2                                   914
# 1           1;2                                   914
# 2           1;2                                   914
# 3           1;2                                   914
# 4           1;2                                   914
# ...         ...                                   ...
# 11330         1  3407;3408;3411;3418;3419;3421;144970
# 11331       NaN                                   NaN
# 11332       NaN                                   NaN
# 11333       NaN                                   NaN
# 11334         2                                   NaN
#
#                    Admin2 Code  \
# 0            13006;13009;13010
# 1            13006;13009;13010
# 2            13006;13009;13010
# 3            13006;13009;13010
# 4            13006;13009;13010
# ...                        ...
# 11330                      NaN
# 11331                      NaN
# 11332                      NaN
# 11333                      NaN
# 11334  82648;82649;82650;82651
#
#                                            Geo Locations
# 0      Jiangxi Sheng (Adm1). Quanzhou, Xiamen, Zhangz...
# 1      Jiangxi Sheng (Adm1). Quanzhou, Xiamen, Zhangz...
# 2      Jiangxi Sheng (Adm1). Quanzhou, Xiamen, Zhangz...
# 3      Jiangxi Sheng (Adm1). Quanzhou, Xiamen, Zhangz...
# 4      Jiangxi Sheng (Adm1). Quanzhou, Xiamen, Zhangz...
# ...                                                  ...
# 11330  Abyan, Al Dhale'e, Al Hudaydah, Hadramaut, Haj...
# 11331                                                NaN
# 11332                                                NaN
# 11333                                                NaN
# 11334  Cristo Rei, Dom Aleixo, Nein Feto, Vera Cruz (...
#
# [11335 rows x 51 columns]

# %%
d3.to_csv("processed/combined_results.csv", index=False)
